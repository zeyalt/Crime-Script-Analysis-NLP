# %% [markdown]
# # Data Extraction

# %% [markdown]
# The objective of this Python notebook is to extract scam reports from the 'Scam Alert' website using web-scrapping techniques.

# %% [markdown]
# ## Import the necessary libraries

# %%
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
import math
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the url of interest
url = "https://www.scamalert.sg/stories"

# %%
# Instantiate a webdriver for Google Chrome
#driver = webdriver.Chrome()
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 83.0.4103
# [WDM] - Get LATEST driver version for 83.0.4103
# [WDM] - Driver [C:\Users\User\.wdm\drivers\chromedriver\win32\83.0.4103.39\chromedriver.exe] found in cache

# %%
# Open the url page
driver.get(url)

# %%
# Create an empty list to store the url links later
links = []

# %%
# Define the xpath of an element on a webpage 
next_xpath = '/html/body/form/main/div[2]/div/div[4]/div[2]/div/div/h4/a'

# %%
# Make the content from page source easy to read with BeautifulSoup
soup = BeautifulSoup(driver.page_source)

# %%
# Extract the total number of results from page source
num_result = int(soup.find('div', class_="col-lg-5 text-muted mb-2 pt-2").text.split()[3])

# %%
# Determine the number of web pages 
num_pages = math.ceil(num_result / 6)
print("Total number of pages:", num_pages)
# Out:
# Total number of pages: 800

# %% [markdown]
# ## Extract URL from each page

# %%
# For loop to iterate through each page 
# for i in range(num_pages):
for i in range(100):
    
    # Display current page number
    print("Page number:", i+1)
    
    # Make the content from page source easy to read with BeautifulSoup
    soup = BeautifulSoup(driver.page_source)
    
    # Find all h4 containers with class 'card-title'.
    for link in soup.find_all('h4', class_='card-title'):
        
        # Extract the 'href' link and append it to the empty list
        links.append(link.a['href'])
    
    # As long as it is not the last page, find the button that links to the next page, and click it
    if i != (num_pages - 1):
        button = driver.find_element_by_link_text(str(i+2)) 
        driver.execute_script("arguments[0].click();", button)
        element = WebDriverWait(driver, 20).until(lambda x: x.find_element_by_xpath(next_xpath))
# Out:
# Page number: 1
# Page number: 2
# Page number: 3
# Page number: 4
# Page number: 5
# Page number: 6
# Page number: 7
# Page number: 8
# Page number: 9
# Page number: 10
# Page number: 11
# Page number: 12
# Page number: 13
# Page number: 14
# Page number: 15
# Page number: 16
# Page number: 17
# Page number: 18
# Page number: 19
# Page number: 20
# Page number: 21
# Page number: 22
# Page number: 23
# Page number: 24
# Page number: 25
# Page number: 26
# Page number: 27
# Page number: 28
# Page number: 29
# Page number: 30
# Page number: 31
# Page number: 32
# Page number: 33
# Page number: 34
# Page number: 35
# Page number: 36
# Page number: 37
# Page number: 38
# Page number: 39
# Page number: 40
# Page number: 41
# Page number: 42
# Page number: 43
# Page number: 44
# Page number: 45
# Page number: 46
# Page number: 47
# Page number: 48
# Page number: 49
# Page number: 50
# Page number: 51
# Page number: 52
# Page number: 53
# Page number: 54
# Page number: 55
# Page number: 56
# Page number: 57
# Page number: 58
# Page number: 59
# Page number: 60
# Page number: 61
# Page number: 62
# Page number: 63
# Page number: 64
# Page number: 65
# Page number: 66
# Page number: 67
# Page number: 68
# Page number: 69
# Page number: 70
# Page number: 71
# Page number: 72
# Page number: 73
# Page number: 74
# Page number: 75
# Page number: 76
# Page number: 77
# Page number: 78
# Page number: 79
# Page number: 80
# Page number: 81
# Page number: 82
# Page number: 83
# Page number: 84
# Page number: 85
# Page number: 86
# Page number: 87
# Page number: 88
# Page number: 89
# Page number: 90
# Page number: 91
# Page number: 92
# Page number: 93
# Page number: 94
# Page number: 95
# Page number: 96
# Page number: 97
# Page number: 98
# Page number: 99
# Page number: 100

# %%
# Convert the list into a pandas dataframe
all_url_links = pd.DataFrame({'url': links})
print(all_url_links)
# Out:
#                                           url
# 0    /stories-details/Story-17Jul2020150318PM
# 1    /stories-details/Story-17Jul2020133721PM
# 2    /stories-details/Story-17Jul2020094730AM
# 3    /stories-details/Story-16Jul2020203342PM
# 4    /stories-details/Story-16Jul2020031601AM
# ..                                        ...
# 595  /stories-details/Story-18Feb2020121823PM
# 596  /stories-details/Story-18Feb2020120844PM
# 597  /stories-details/Story-18Feb2020113217AM
# 598  /stories-details/Story-18Feb2020103222AM
# 599  /stories-details/Story-18Feb2020100945AM
#
# [600 rows x 1 columns]

# %%
# Save the dataframe into a csv file
all_url_links.to_csv("Data/scam_url_links.csv")

# %% [markdown]
# ## Scaping from each URL

# %%
url_links = pd.read_csv("Data/scam_url_links.csv").drop(columns="Unnamed: 0")

# %%
full_url = []
header = "https://www.scamalert.sg"
for index, link in url_links.iterrows():
    full_url.append(header + link['url'])

# %%
scam_type = []
incident_description = []
scammer_details = []
submission_details = []

for i, url in enumerate(full_url):
    print("S/N:", i+1)
    print("url:", url)
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    # Only extract the details if it is a valid webpage 
    # A webpage is assumed to be valid if it contains the 'sf_colsIn jumbotron bg-dark' class in 'div' container
    if soup.find('div', class_="sf_colsIn jumbotron bg-dark") != None:
    
        sub_detail = soup.find_all('p', class_='lead')[0] if soup.find_all('p', class_='lead')[0] else '-'
        submission_details.append(sub_detail.text)
    
        s_type = soup.find_all('a', class_='text-primary')[0] if soup.find_all('a', class_='text-primary')[0] else '-'
        scam_type.append(s_type.text)
        
        i_description = soup.find('div', class_="lead") if soup.find('div', class_="lead") else '-'
        incident_description.append(i_description.text)
        
        s_details = soup.find_all('p', class_="lead")[1] if soup.find_all('p', class_="lead")[1] else '-'
        scammer_details.append(s_details.text)
# Out:
# S/N: 1
# url: https://www.scamalert.sg/stories-details/Story-17Jul2020150318PM
# S/N: 2
# url: https://www.scamalert.sg/stories-details/Story-17Jul2020133721PM
# S/N: 3
# url: https://www.scamalert.sg/stories-details/Story-17Jul2020094730AM
# S/N: 4
# url: https://www.scamalert.sg/stories-details/Story-16Jul2020203342PM
# S/N: 5
# url: https://www.scamalert.sg/stories-details/Story-16Jul2020031601AM
# S/N: 6
# url: https://www.scamalert.sg/stories-details/Story-15Jul2020222224PM
# S/N: 7
# url: https://www.scamalert.sg/stories-details/Story-15Jul2020162116PM
# S/N: 8
# url: https://www.scamalert.sg/stories-details/Story-15Jul2020150200PM
# S/N: 9
# url: https://www.scamalert.sg/stories-details/Story-15Jul2020140600PM
# S/N: 10
# url: https://www.scamalert.sg/stories-details/Story-15Jul2020132017PM
# S/N: 11
# url: https://www.scamalert.sg/stories-details/Story-15Jul2020102421AM
# S/N: 12
# url: https://www.scamalert.sg/stories-details/Story-14Jul2020153904PM
# S/N: 13
# url: https://www.scamalert.sg/stories-details/Story-14Jul2020124840PM
# S/N: 14
# url: https://www.scamalert.sg/stories-details/Story-14Jul2020104634AM
# S/N: 15
# url: https://www.scamalert.sg/stories-details/Story-13Jul2020123824PM
# S/N: 16
# url: https://www.scamalert.sg/stories-details/Story-13Jul2020121748PM
# S/N: 17
# url: https://www.scamalert.sg/stories-details/Story-13Jul2020114321AM
# S/N: 18
# url: https://www.scamalert.sg/stories-details/Story-12Jul2020062855AM
# S/N: 19
# url: https://www.scamalert.sg/stories-details/Story-11Jul2020164006PM
# S/N: 20
# url: https://www.scamalert.sg/stories-details/Story-11Jul2020120015PM
# S/N: 21
# url: https://www.scamalert.sg/stories-details/Story-10Jul2020085628AM
# S/N: 22
# url: https://www.scamalert.sg/stories-details/Story-09Jul2020144856PM
# S/N: 23
# url: https://www.scamalert.sg/stories-details/Story-08Jul2020151608PM
# S/N: 24
# url: https://www.scamalert.sg/stories-details/Story-08Jul2020145857PM
# S/N: 25
# url: https://www.scamalert.sg/stories-details/Story-08Jul2020130347PM
# S/N: 26
# url: https://www.scamalert.sg/stories-details/Story-08Jul2020110235AM
# S/N: 27
# url: https://www.scamalert.sg/stories-details/Story-08Jul2020090230AM
# S/N: 28
# url: https://www.scamalert.sg/stories-details/Story-08Jul2020084849AM
# S/N: 29
# url: https://www.scamalert.sg/stories-details/Story-07Jul2020174740PM
# S/N: 30
# url: https://www.scamalert.sg/stories-details/Story-07Jul2020134720PM
# S/N: 31
# url: https://www.scamalert.sg/stories-details/Story-07Jul2020130540PM
# S/N: 32
# url: https://www.scamalert.sg/stories-details/Story-07Jul2020130503PM
# S/N: 33
# url: https://www.scamalert.sg/stories-details/Story-07Jul2020002010AM
# S/N: 34
# url: https://www.scamalert.sg/stories-details/beware-of-emails-purportedly-from-moe
# S/N: 35
# url: https://www.scamalert.sg/stories-details/Story-06Jul2020173946PM
# S/N: 36
# url: https://www.scamalert.sg/stories-details/Story-06Jul2020150248PM
# S/N: 37
# url: https://www.scamalert.sg/stories-details/Story-06Jul2020005748AM
# S/N: 38
# url: https://www.scamalert.sg/stories-details/Story-04Jul2020195645PM
# S/N: 39
# url: https://www.scamalert.sg/stories-details/Story-04Jul2020130300PM
# S/N: 40
# url: https://www.scamalert.sg/stories-details/Story-04Jul2020123542PM
# S/N: 41
# url: https://www.scamalert.sg/stories-details/Story-04Jul2020103355AM
# S/N: 42
# url: https://www.scamalert.sg/stories-details/Story-04Jul2020101911AM
# S/N: 43
# url: https://www.scamalert.sg/stories-details/Story-02Jul2020144342PM
# S/N: 44
# url: https://www.scamalert.sg/stories-details/Story-02Jul2020143915PM
# S/N: 45
# url: https://www.scamalert.sg/stories-details/Story-02Jul2020122003PM
# S/N: 46
# url: https://www.scamalert.sg/stories-details/Story-01Jul2020215759PM
# S/N: 47
# url: https://www.scamalert.sg/stories-details/Story-01Jul2020172354PM
# S/N: 48
# url: https://www.scamalert.sg/stories-details/Story-01Jul2020111309AM
# S/N: 49
# url: https://www.scamalert.sg/stories-details/Story-01Jul2020083100AM
# S/N: 50
# url: https://www.scamalert.sg/stories-details/Story-30Jun2020153553PM
# S/N: 51
# url: https://www.scamalert.sg/stories-details/Story-30Jun2020115042AM
# S/N: 52
# url: https://www.scamalert.sg/stories-details/Story-29Jun2020205942PM
# S/N: 53
# url: https://www.scamalert.sg/stories-details/Story-29Jun2020160543PM
# S/N: 54
# url: https://www.scamalert.sg/stories-details/Story-29Jun2020144601PM
# S/N: 55
# url: https://www.scamalert.sg/stories-details/Story-29Jun2020143416PM
# S/N: 56
# url: https://www.scamalert.sg/stories-details/Story-29Jun2020125820PM
# S/N: 57
# url: https://www.scamalert.sg/stories-details/Story-26Jun2020174445PM
# S/N: 58
# url: https://www.scamalert.sg/stories-details/Story-26Jun2020142058PM
# S/N: 59
# url: https://www.scamalert.sg/stories-details/Story-26Jun2020093657AM
# S/N: 60
# url: https://www.scamalert.sg/stories-details/Story-25Jun2020122758PM
# S/N: 61
# url: https://www.scamalert.sg/stories-details/Story-25Jun2020011209AM
# S/N: 62
# url: https://www.scamalert.sg/stories-details/Story-24Jun2020043341AM
# S/N: 63
# url: https://www.scamalert.sg/stories-details/Story-23Jun2020223246PM
# S/N: 64
# url: https://www.scamalert.sg/stories-details/Story-23Jun2020163118PM
# S/N: 65
# url: https://www.scamalert.sg/stories-details/Story-22Jun2020215131PM
# S/N: 66
# url: https://www.scamalert.sg/stories-details/Story-22Jun2020154946PM
# S/N: 67
# url: https://www.scamalert.sg/stories-details/Story-22Jun2020134126PM
# S/N: 68
# url: https://www.scamalert.sg/stories-details/Story-22Jun2020122226PM
# S/N: 69
# url: https://www.scamalert.sg/stories-details/Story-22Jun2020101459AM
# S/N: 70
# url: https://www.scamalert.sg/stories-details/Story-22Jun2020094555AM
# S/N: 71
# url: https://www.scamalert.sg/stories-details/not-all-friends-who-you-meet-online-are-genuine
# S/N: 72
# url: https://www.scamalert.sg/stories-details/Story-21Jun2020143420PM
# S/N: 73
# url: https://www.scamalert.sg/stories-details/Story-21Jun2020122402PM
# S/N: 74
# url: https://www.scamalert.sg/stories-details/Story-20Jun2020230105PM
# S/N: 75
# url: https://www.scamalert.sg/stories-details/Story-20Jun2020211842PM
# S/N: 76
# url: https://www.scamalert.sg/stories-details/Story-20Jun2020120054PM
# S/N: 77
# url: https://www.scamalert.sg/stories-details/Story-19Jun2020204244PM
# S/N: 78
# url: https://www.scamalert.sg/stories-details/Story-19Jun2020181745PM
# S/N: 79
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020153820PM
# S/N: 80
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020135956PM
# S/N: 81
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020134252PM
# S/N: 82
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020132126PM
# S/N: 83
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020130738PM
# S/N: 84
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020121622PM
# S/N: 85
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020110917AM
# S/N: 86
# url: https://www.scamalert.sg/stories-details/Story-18Jun2020105735AM
# S/N: 87
# url: https://www.scamalert.sg/stories-details/Story-17Jun2020155452PM
# S/N: 88
# url: https://www.scamalert.sg/stories-details/Story-17Jun2020143730PM
# S/N: 89
# url: https://www.scamalert.sg/stories-details/Story-17Jun2020131844PM
# S/N: 90
# url: https://www.scamalert.sg/stories-details/Story-16Jun2020192247PM
# S/N: 91
# url: https://www.scamalert.sg/stories-details/Story-16Jun2020182605PM
# S/N: 92
# url: https://www.scamalert.sg/stories-details/Story-16Jun2020164520PM
# S/N: 93
# url: https://www.scamalert.sg/stories-details/Story-16Jun2020142949PM
# S/N: 94
# url: https://www.scamalert.sg/stories-details/Story-16Jun2020114059AM
# S/N: 95
# url: https://www.scamalert.sg/stories-details/Story-16Jun2020093429AM
# S/N: 96
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020163942PM
# S/N: 97
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020143916PM
# S/N: 98
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020142941PM
# S/N: 99
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020141125PM
# S/N: 100
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020134948PM
# S/N: 101
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020121208PM
# S/N: 102
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020115712AM
# S/N: 103
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020113145AM
# S/N: 104
# url: https://www.scamalert.sg/stories-details/Story-15Jun2020100118AM
# S/N: 105
# url: https://www.scamalert.sg/stories-details/Story-146月2020124055下午
# S/N: 106
# url: https://www.scamalert.sg/stories-details/Story-13Jun2020165102PM
# S/N: 107
# url: https://www.scamalert.sg/stories-details/new-story---alcatrazflo@hotmail.com
# S/N: 108
# url: https://www.scamalert.sg/stories-details/Story-12Jun2020182342PM
# S/N: 109
# url: https://www.scamalert.sg/stories-details/Story-12Jun2020115909AM
# S/N: 110
# url: https://www.scamalert.sg/stories-details/Story-12Jun2020002038AM
# S/N: 111
# url: https://www.scamalert.sg/stories-details/Story-11Jun2020141605PM
# S/N: 112
# url: https://www.scamalert.sg/stories-details/Story-11Jun2020122710PM
# S/N: 113
# url: https://www.scamalert.sg/stories-details/Story-11Jun2020110937AM
# S/N: 114
# url: https://www.scamalert.sg/stories-details/Story-11Jun2020100652AM
# S/N: 115
# url: https://www.scamalert.sg/stories-details/Story-11Jun2020081302AM
# S/N: 116
# url: https://www.scamalert.sg/stories-details/Story-10Jun2020101213AM
# S/N: 117
# url: https://www.scamalert.sg/stories-details/Story-10Jun2020100014AM
# S/N: 118
# url: https://www.scamalert.sg/stories-details/Story-10Jun2020082845AM
# S/N: 119
# url: https://www.scamalert.sg/stories-details/Story-09Jun2020193539PM
# S/N: 120
# url: https://www.scamalert.sg/stories-details/Story-09Jun2020102033AM
# S/N: 121
# url: https://www.scamalert.sg/stories-details/Story-09Jun2020092038AM
# S/N: 122
# url: https://www.scamalert.sg/stories-details/Story-08Jun2020210918PM
# S/N: 123
# url: https://www.scamalert.sg/stories-details/Story-08Jun2020140021PM
# S/N: 124
# url: https://www.scamalert.sg/stories-details/Story-08Jun2020131134PM
# S/N: 125
# url: https://www.scamalert.sg/stories-details/Story-07Jun2020200132PM
# S/N: 126
# url: https://www.scamalert.sg/stories-details/Story-06Jun2020191307PM
# S/N: 127
# url: https://www.scamalert.sg/stories-details/Story-06Jun2020140025PM
# S/N: 128
# url: https://www.scamalert.sg/stories-details/Story-06Jun2020121709PM

# %%
scam_df = pd.DataFrame({
        'submission_details': submission_details,
        'scam_type': scam_type,
        'incident_description': incident_description,
        'scammer_details': scammer_details
        })
    
scam_df
# Out:
#           submission_details           scam_type  \
# 0    Anonymous | 17 Jul 2020  Impersonation Scam
# 1    Anonymous | 17 Jul 2020       Phishing Scam
# 2    Anonymous | 17 Jul 2020       Phishing Scam
# 3    Anonymous | 16 Jul 2020  Impersonation Scam
# 4    Anonymous | 16 Jul 2020       Phishing Scam
# ..                       ...                 ...
# 123  Anonymous | 08 Jun 2020  Impersonation Scam
# 124  Anonymous | 07 Jun 2020  Internet Love Scam
# 125  Anonymous | 06 Jun 2020  Impersonation Scam
# 126  Anonymous | 06 Jun 2020       Phishing Scam
# 127  Anonymous | 06 Jun 2020  Impersonation Scam
#
#                                   incident_description  \
# 0    \r\n                They call me by whatsapp  ...
# 1    \r\n                it happened this morning 0...
# 2    \r\n                I rceived a call from a la...
# 3    \r\n                details: I received a call...
# 4    \n1) An impersonated junior technical staff ca...
# ..                                                 ...
# 123  \nA caller by the name mike with a strong indi...
# 124  \nLadies/gentlman \n\nplease be careful when y...
# 125  \r\n                Text message was sent to m...
# 126  \r\n                I received a call from 911...
# 127  \r\n                the caller called my mobil...
#
#                                        scammer_details
# 0    \r\n                        Name: I only know ...
# 1    \r\n                        Name: Ministry of ...
# 2    \r\n                        Name: SIngtel\r\n ...
# 3    \r\n                        Name: Singapore hi...
# 4    \r\n                        Name: SINGTEL, RON...
# ..                                                 ...
# 123  \r\n                        Name: SinGTEL\r\n ...
# 124  \r\n                        Name: CHINA PROFIL...
# 125  \r\n                        Name: cid police o...
# 126  \r\n                        Name: Singtel\r\n ...
# 127  \r\n                        Name: SINGTEL\r\n ...
#
# [128 rows x 4 columns]

# %% [markdown]
# ## Save dataframe as a CSV file

# %%
# Save the dataframe into a csv file
scam_df.to_csv("Data/scam_raw_dataset.csv")
